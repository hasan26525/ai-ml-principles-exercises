# %% [markdown]
# <a href="https://colab.research.google.com/github/hasan26525/ai-ml-principles-exercises/blob/main/Testing/CV_crashcourse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://picfiles.alphacoders.com/311/311438.jpg -O "road.jpg"
# Out:
# --2025-05-23 21:47:29--  https://picfiles.alphacoders.com/311/311438.jpg
# Resolving picfiles.alphacoders.com (picfiles.alphacoders.com)... 104.20.76.132, 172.67.48.187, 104.20.75.132, ...
# Connecting to picfiles.alphacoders.com (picfiles.alphacoders.com)|104.20.76.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2025458 (1.9M) [image/jpeg]
# Saving to: ‘road.jpg’
#
# road.jpg            100%[===================>]   1.93M  6.19MB/s    in 0.3s
#
# 2025-05-23 21:47:30 (6.19 MB/s) - ‘road.jpg’ saved [2025458/2025458]

# %%
from PIL import Image
import numpy as np

# %%
road = Image.open("road.jpg")

# %%
img_shape = np.array(road)#.shape
Image.fromarray(img_shape, "RGB")
redy = img_shape.copy()

# %%
red = redy[:,:,0]
red_ch = Image.fromarray(red,"L")
red.shape
# Out:
# (2814, 3750)

# %%
red_ch.resize((1000,1000))
width, height = 200,100
Image.fromarray(img_shape).resize((width,height))
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>

# %%
import sklearn as sk, sklearn.datasets as datasets
dt = datasets.load_digits()
print(type(dt))
#print(dt)
print(dt.keys())
print(dt.images.shape)
reformatted_img = np.astype(dt.images[0]*255/16,np.uint8)
print(reformatted_img.shape)
resized_img = Image.fromarray(reformatted_img).resize((100,100),resample = Image.NEAREST)
resized_img
# Out:
# <class 'sklearn.utils._bunch.Bunch'>
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])
# (1797, 8, 8)
# (8, 8)
# <PIL.Image.Image image mode=L size=100x100>
